# %% [markdown]
# # **Common Prosperity Simulation**
# ## Computational Physics Lab
# Authors: Yuan-Yen Peng, Chih-Tian Ho
# E-mail: garyphys0915@gapp.nthu.edu.tw, chihtian.ho@gapp.nthu.edu.tw
# Dept of Physics, NTHU, Taiwan
# Date: Jan. 09, 2023
# Version: 5.1.0
# License: MIT

# %%
# %reset -f
problem_name = 'Common_Prosperity'

# %%
import os, sys, stat
import shutil
from pathlib import Path

if os.path.exists(Path(f'./fig_{problem_name}')) == True:
    os.chmod(f'./fig_{problem_name}', stat.S_IRWXU)
    shutil.rmtree(f'./fig_{problem_name}')
    print('old folder has been removed!')
# Out:
# old folder has been removed!

# %%
import numpy as np
from scipy.misc import derivative
from scipy.optimize import curve_fit
from scipy.interpolate import CubicSpline
from scipy.interpolate import UnivariateSpline, InterpolatedUnivariateSpline
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from numba import njit, prange
import time
from PIL import Image
import glob

# %% [markdown]
# ### initial conditions

# %%
# setup
io_title = problem_name
io_freq = 4 # how many steps to record the data, unit [1 month]
# unit
month = 30 # [days]
yr = 12 * month # unit: days
# size
size = int(1e3)
width, length = size, size # grid's width and length
N = int(width * length) # how many sites
tmax =  0.1 * 3 * yr # [days]
n = int(tmax / 7) # time steps [days]

# initial energy conditions
J = 1 # configuration constant (positive means paramagnetism)

# initial bkg condition, set the standard diviation for x & y are both 3 
SsizeE = 0.1
sigma_x, sigma_y = SsizeE * width, SsizeE * length

# intial self condition, set eta, will be adjust by results (absorbing coeff)
eta = 0.07 # absorbing rate constant

# subsidy constant for equality and justice case respectively
# quarter (Q1, Q2, Q3, Q4) --> 3 * 4 weeks
s_time = 3 * 4 * 7
se = int(10/10) * 0.01
sj = int(10/2) * se

# probability
p = 0.01 # rich --> poor
q = 0.01 # poor --> rich

# %% [markdown]
# ### Grid generator

# %%
def grid_generator(width, length, init_rank:float = 3.0, dec: int = 2):
  '''
  This is a grid generator
  :para width: width of the grid
  :para length: lerngth of the grid
  :para init_rank: bounds of initial rank of the grid; i.e., if use 3, --> [-3, 3]
  :para dec: decimal for the function <round>
  '''

  grid_positive = np.round(init_rank * np.random.random(int(N/2)), dec)
  grid_negative = np.round(-init_rank * np.random.random(int(N/2)), dec)
  grid = np.append(grid_positive, grid_negative)
  np.random.shuffle(grid) # set it to random
  grid = grid.reshape((width, length))

  # add the boundaries to four margins with minimum initial rank - 1
  tor = - (init_rank + 1)
  res = np.array([tor * np.ones(length)])
  grid_boundary = np.concatenate((res, grid, res), axis=0)
  grid_boundary = np.insert(grid_boundary, (0, length), tor, axis=1)

  return grid, grid_boundary

# %%
def plot(arr, header, lim, size = 8, dpi = 80):
  '''
  :para arr: input data: 2D Array
  '''

  figure(figsize=(size, size), dpi=dpi)
  plt.imshow(arr, cmap='coolwarm', extent=[-width/2,width/2,-length/2,length/2], alpha=.85)
  plt.colorbar()
  plt.clim(-lim-2.5, lim+2.5)
  plt.title(f'{header}')

  return

# %%
def plot_ct(arr, header, lim, size = 8, dpi = 80):
  '''
  :para arr: input data: 2D Array
  '''

  figure(figsize=(size, size), dpi=dpi)
  plt.imshow(arr, cmap='coolwarm', extent=[-width/2,width/2,-length/2,length/2], alpha=.75)
  plt.colorbar()
  # plt.contour(arr, colors='w', extent=[-width/2,width/2,-length/2,length/2], alpha=.85)
  plt.clim(-lim-1, lim+1)
  plt.title(f'{header}')

  return

# %% [markdown]
# ### output

# %% [markdown]
# make the directories

# %%
io_folder_fig = "fig_" + io_title
Path(io_folder_fig).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# output figures

# %%
def output_fig(n, arr, lim, time, title):
  """
  Write simulation data into a file named "fig"
  """
  header = f"{title}, time = {int(time)}"
  plot(arr, header, lim)
  fig = f'{io_folder_fig}/fig_{io_title}_{title}_{str(n).zfill(3)}.png'
  plt.savefig(fig)
  plt.close() # in order to save memory

  return

# %% [markdown]
# ### main exchange functions

# %% [markdown]
# #### Energy (each time)

# %%
@njit(parallel = True) # faster than jit if using "parallel"
def energy(spin, N, J, h):
  '''
  :para spin: is a spin matrix
  :para N: is the total number of sites
  :para J: is configuration constant (positive means paramagnetism)
  :para h: is external field
  '''

  l = int(np.sqrt(N))
  energy = np.zeros((l+2, l+2))
  for i in prange(1, l+1):
    for j in prange(1, l+1):
      s_cen  = spin[i  , j  ]
      s_up   = spin[i-1, j  ]
      s_rig  = spin[i  , j+1]
      s_down = spin[i+1, j  ]
      s_lef  = spin[i  , j-1]

      energy[i, j] = -J * s_up * s_rig * s_down * s_lef - h * s_cen

  return energy

# %% [markdown]
# #### Magnetization (each time)

# %%
def mag(spin):
  '''
  :para m: magnetization per spin (site)
  :para M: total magnetization
  '''

  M = np.sum(spin)
  m = np.average(spin)
  return m, M

# %% [markdown]
# #### Susceptibility

# %%
# @njit(parallel = True)
def X(f, h, x, size):
    dx = 1e-3
    for i in range(size):
        x[i] = derivative(f, h[i], dx)
    return x

# %% [markdown]
# #### Background function (each time)

# %%
@njit(parallel = True)
def bkg(N, sigma_x, sigma_y):
  '''
  :para N: is the total number of sites
  :para sigma_x: is a standard deviation in x-direction
  :para sigma_y: is a standard deviation in y-direction
  '''

  # l is the length; l_incluse is the length with margins; i.e., +2
  l = int(np.sqrt(N))
  l_include = l + 2
  coeff = 8e3
  BKG = np.ones((l_include, l_include))
  sigma = np.sqrt(np.square(sigma_x) + np.square(sigma_y))
  for i in prange(l):
        for j in prange(l):
            r = np.sqrt(np.square(i - l_include/2 + 2) + np.square(j - l_include/2 + 2))
            BKG[i, j] = coeff * (1/(np.sqrt(2 * np.pi) * sigma)) * (np.exp(-np.square(r) / (2 * np.square(sigma))))
  return BKG

# %% [markdown]
# #### Fitting

# %%
def func_exp(x, a, b, c, d):
  return -a * np.exp(-b * x + c) + d

def func_repo(x, a, b, c, d):
  return -a / (b*x + c) + d

# %%
def f(x, popt):
   return -popt[0] * np.exp(-popt[1] * x + popt[2]) + popt[3]

# %%
def CS(x, y):
  # cs = CubicSpline(x, y)
  cs = InterpolatedUnivariateSpline(x, y)
  der = UnivariateSpline(x, y).derivatives(x)
  return cs, der

# %% [markdown]
# #### Self (spin) function (each time)

# %%
@njit(parallel = True)
def self(N, t, tmax, spin, bkg, eta):
    '''
        :para N: is the total number of sites
        :para t: is the time in the moment
        :para spin: is the spin matrix
        :para bkg: is the background function
        :para eta: absorbing rate constant

        1) set another array called new playground as nspin to save the new Hierarchy, 
            and update when all units are calculated.
        2) note that no need for bkg since they are indep. for each
    '''
    l = int(np.sqrt(N))
    nspin = np.copy(spin) # this is temp of spin (which depend on spin)
    for i in prange(1, l+1):
        for j in prange(1, l+1):

            # setup relative spins positions
            s_cen  = spin[i  , j  ]
            s_up   = spin[i-1, j  ]
            s_rig  = spin[i  , j+1]
            s_down = spin[i+1, j  ]
            s_lef  = spin[i  , j-1]

            # temp spin matrix
            nspin[i,j] += (0.5 / (3 * np.sqrt(2*np.pi)) * np.exp(-(np.square(s_cen)/(2 * np.square(3)))) * (-(4*s_cen - s_rig -s_lef - s_up - s_down))
                            + 0.5 * eta * (0.05 * np.exp(-5) * np.exp(s_cen)
                                            + (0.95 / (3 * np.sqrt(2 * np.pi))) * np.exp(-np.square(s_cen)/(2 * np.square(3)))) * bkg[i,j] * np.sin(2 * np.pi * t/tmax))
                            
            # rich --> poor
            if nspin[i,j] >= 5 and (s_rig + s_lef + s_up + s_down)/4 > 4:
                    # C are the random number [0, 1]
                    C = np.random.randint(100) / 100
                    if C <= p:
                        # the ``cross region'' will also be implicated.
                        nspin[i+1, j  ] = 0.3 * nspin[i+1, j  ] 
                        nspin[i  , j+1] = 0.3 * nspin[i  , j+1]
                        nspin[i  , j  ] = -4
                        nspin[i-1, j  ] = 0.3 * nspin[i-1, j  ]
                        nspin[i  , j-1] = 0.3 * nspin[i  , j-1]
                    else:
                        nspin[i, j] = 5
            elif nspin[i,j] >= 5 and (s_rig + s_lef + s_up + s_down)/4 <= 4:
                        nspin[i, j] = 5

            # poor --> rich
            elif nspin[i,j] <= -5 and (s_rig + s_lef + s_up + s_down)/4 < -4:
                    # C are the random number [0, 1]
                    C = np.random.randint(100) / 100
                    if C <= q:
                        nspin[i+1, j  ] = 0.3 * nspin[i+1, j  ] 
                        nspin[i  , j+1] = 0.3 * nspin[i  , j+1]
                        nspin[i  , j  ] = 4
                        nspin[i-1, j  ] = 0.3 * nspin[i-1, j  ]
                        nspin[i  , j-1] = 0.3 * nspin[i  , j-1]
                    else:
                        nspin[i, j] = -5    
            elif nspin[i,j] <= -5 and (s_rig + s_lef + s_up + s_down)/4 >= -4:
                        nspin[i, j] = -5
            # site max and min is +5 and -5

            '''
            bkg is only decay with the time (add the constraint of cos finction with the period t_max)
            '''      

            bkg[i,j] -= eta * (0.05 * np.exp(-5) * np.exp(s_cen) 
                                + (0.95 / (3 * np.sqrt(2 * np.pi))) * np.exp(-np.square(s_cen)/(2 * np.square(3)))) * bkg[i,j] * np.sin(2 * np.pi * t/tmax)

    spin = np.copy(nspin) # temp of spin = new spin (the next next matrix)

    return spin, bkg

# %% [markdown]
# #### Equality (self)

# %%
@njit(parallel = True)
def self_eq(N, t, tmax, spin, bkg, eta, se, s_time):
  '''
    :para N: is the total number of sites
    :para t: is the time in the moment
    :para spin: is the spin matrix
    :para bkg: is the background function
    :para eta: absorbing rate constant

    1) set another array called new playground as nspin to save the new Hierarchy, 
        and update when all units are calculated.
    2) note that no need for bkg since they are indep. for each
  '''
  l = int(np.sqrt(N))
  nspin = np.copy(spin) # this is temp of spin (which depend on spin)
  for i in prange(1, l+1):
      for j in prange(1, l+1):

          # setup relative spins positions
          s_cen  = spin[i  , j  ]
          s_up   = spin[i-1, j  ]
          s_rig  = spin[i  , j+1]
          s_down = spin[i+1, j  ]
          s_lef  = spin[i  , j-1]

          # temp spin matrix
          nspin[i,j] += (0.5 / (3 * np.sqrt(2*np.pi)) * np.exp(-(np.square(s_cen)/(2 * np.square(3)))) * (-(4*s_cen - s_rig -s_lef - s_up - s_down))
                                      + 0.5 * eta * (0.05 * np.exp(-5) * np.exp(s_cen)
                                              + (0.95/(3 * np.sqrt(2 * np.pi))) * np.exp(-np.square(s_cen)/(2 * np.square(3)))) * bkg[i,j] * np.sin(2 * np.pi * t/tmax))

          # Equality (all sites in mid-class [-3,3] will add se)
          # add another subsidy constant "se"
          if int(t) % s_time == 0:
            nspin[i,j] += se
            # print(f"t = {int(t)}, subsidize!")
            
          # rich --> poor
          if nspin[i,j] >= 5 and (s_rig + s_lef + s_up + s_down)/4 > 4:
                # C are the random number [0, 1]
                C = np.random.randint(100) / 100
                if C <= p:
                    # the ``cross region'' will also be implicated.
                    nspin[i+1, j  ] = 0.3 * nspin[i+1, j  ] 
                    nspin[i  , j+1] = 0.3 * nspin[i  , j+1]
                    nspin[i  , j  ] = -4
                    nspin[i-1, j  ] = 0.3 * nspin[i-1, j  ]
                    nspin[i  , j-1] = 0.3 * nspin[i  , j-1]
                else:
                    nspin[i, j] = 5
          elif nspin[i,j] >= 5 and (s_rig + s_lef + s_up + s_down)/4 <= 4:
                    nspin[i, j] = 5

          # poor --> rich
          elif nspin[i,j] <= -5 and (s_rig + s_lef + s_up + s_down)/4 < -4:
                # C are the random number [0, 1]
                C = np.random.randint(100) / 100
                if C <= q:
                        nspin[i+1, j  ] = 0.3 * nspin[i+1, j  ] 
                        nspin[i  , j+1] = 0.3 * nspin[i  , j+1]
                        nspin[i  , j  ] = 4
                        nspin[i-1, j  ] = 0.3 * nspin[i-1, j  ]
                        nspin[i  , j-1] = 0.3 * nspin[i  , j-1]
                else:
                    nspin[i, j] = -5    
          elif nspin[i,j] <= -5 and (s_rig + s_lef + s_up + s_down)/4 >= -4:
                    nspin[i, j] = -5
          # site max and min is +5 and -5

          '''
          bkg is only decay with the time (add the constraint of cos finction with the period t_max)
          '''      

          bkg[i,j] -= eta * (0.05 * np.exp(-5) * np.exp(s_cen) 
                              + (0.95 / (3 * np.sqrt(2 * np.pi))) * np.exp(-np.square(s_cen)/(2 * np.square(3)))) * bkg[i,j] * np.sin(2 * np.pi * t/tmax)

  spin = np.copy(nspin) # temp of spin = new spin (the next next matrix)

  return spin, bkg

# %% [markdown]
# #### Justice (self)

# %%
@njit(parallel = True)
def self_ju(N, t, tmax, spin, bkg, eta, sj, s_time):
  '''
    :para N: is the total number of sites
    :para t: is the time in the moment
    :para spin: is the spin matrix
    :para bkg: is the background function
    :para eta: absorbing rate constant

    1) set another array called new playground as nspin to save the new Hierarchy, 
        and update when all units are calculated.
    2) note that no need for bkg since they are indep. for each
  '''
  l = int(np.sqrt(N))
  nspin = np.copy(spin) # this is temp of spin (which depend on spin)
  for i in prange(1, l+1):
      for j in prange(1, l+1):

          # setup relative spins positions
          s_cen  = spin[i  , j  ]
          s_up   = spin[i-1, j  ]
          s_rig  = spin[i  , j+1]
          s_down = spin[i+1, j  ]
          s_lef  = spin[i  , j-1]

          # temp spin matrix
          nspin[i,j] += (0.5 / (3 * np.sqrt(2*np.pi)) * np.exp(-(np.square(s_cen)/(2 * np.square(3)))) * (-(4*s_cen - s_rig -s_lef - s_up - s_down))
                                      + 0.5 * eta * (0.05 * np.exp(-5) * np.exp(s_cen)
                                              + (0.95/(3 * np.sqrt(2 * np.pi))) * np.exp(-np.square(s_cen)/(2 * np.square(3)))) * bkg[i,j] * np.sin(2 * np.pi * t/tmax))

          # Justice (only the sites in low-class [-3,0) will add sj)
          # add another subsidy constant "sj"
          # middle class store subsidy
          if int(t) % s_time == 0:
            if nspin[i,j] < 0 and nspin[i,j] >= -5:
              nspin[i,j] += sj
              
              # if s_time == s_time:
              #   print(f"t = {int(t)}, subsidize!")
              #   break
              
          # rich --> poor
          if nspin[i,j] >= 5 and (s_rig + s_lef + s_up + s_down)/4 > 4:
                # C are the random number [0, 1]
                C = np.random.randint(100) / 100
                if C <= p:
                    # the ``cross region'' will also be implicated.
                    nspin[i+1, j  ] = 0.3 * nspin[i+1, j  ] 
                    nspin[i  , j+1] = 0.3 * nspin[i  , j+1]
                    nspin[i  , j  ] = -4
                    nspin[i-1, j  ] = 0.3 * nspin[i-1, j  ]
                    nspin[i  , j-1] = 0.3 * nspin[i  , j-1]
                else:
                    nspin[i, j] = 5
          elif nspin[i,j] >= 5 and (s_rig + s_lef + s_up + s_down)/4 <= 4:
                    nspin[i, j] = 5

          # poor --> rich
          elif nspin[i,j] <= -5 and (s_rig + s_lef + s_up + s_down)/4 < -4:
                # C are the random number [0, 1]
                C = np.random.randint(100) / 100
                if C <= q:
                        nspin[i+1, j  ] = 0.3 * nspin[i+1, j  ] 
                        nspin[i  , j+1] = 0.3 * nspin[i  , j+1]
                        nspin[i  , j  ] = 4
                        nspin[i-1, j  ] = 0.3 * nspin[i-1, j  ]
                        nspin[i  , j-1] = 0.3 * nspin[i  , j-1]
                else:
                    nspin[i, j] = -5    
          elif nspin[i,j] <= -5 and (s_rig + s_lef + s_up + s_down)/4 >= -4:
                    nspin[i, j] = -5
          # site max and min is +5 and -5

          '''
          bkg is only decay with the time (add the constraint of cos finction with the period t_max)
          '''

          bkg[i,j] -= eta * (0.05 * np.exp(-5) * np.exp(s_cen) 
                              + (0.95 / (3 * np.sqrt(2 * np.pi))) * np.exp(-np.square(s_cen)/(2 * np.square(3)))) * bkg[i,j] * np.sin(2 * np.pi * t/tmax)

  spin = np.copy(nspin) # temp of spin = new spin (the next next matrix)

  return spin, bkg

# %% [markdown]
# ### Main loop

# %%
# main (loop of time)
def main(N, n, tmax, spin, J, sigma_x, sigma_y, eta, *args):
    '''
    This is the main loop function, and it will also output the figures(.png).

    :para N: is the total number of sites
    :para n: is total number of time steps
    :para T: is the total time
    :para spin: is the spin matrix
    :para J: is configuration constant (positive means paramagnetism)
    :para sigma_x: is a standard deviation in x-direction
    :para sigma_y: is a standard deviation in y-direction
    :para eta: absorbing rate constant
    '''

    dt = 7
    t = 0
    temp_n = 0
    
    # initial setup checking 
    bk = bkg(N, sigma_x, sigma_y)
    h = 0.2 * np.average(bk) # set no bkg influences in the beginning
    Ei =energy(spin, N, J, h)
    Ei = np.delete(Ei, (0, -1), 0)
    Ei = np.delete(Ei, (0, -1), 1)
    Si = np.delete(spin, (0, -1), 0)
    Si = np.delete(Si, (0, -1), 1)
    
    m      = np.array([mag(Si)[0]])
    M      = np.array([mag(Si)[1]])
    H      = np.array([h])
    Energy = np.array([np.average(Ei)])
    
    # initial output
    clim_spin = np.max(np.abs(Si))
    clim_energy = np.max(np.abs(Ei))
    output_fig(temp_n, Si, clim_spin, t, "norm_spin")
    output_fig(temp_n, Ei, clim_energy, t, "norm_energy")
    print("Initial t = 0, succeed to output!")

    t1 = time.time()
    while t < tmax:
      # update data
      epsilon =energy(spin, N, J, h)
      spin = self(N, t, tmax, spin, bk, eta)[0]
      h = 0.2 * np.average(self(N, t, tmax, spin, bk, eta)[1])
      
      # prune margins
      S = np.delete(spin, (0, -1), 0)
      S = np.delete(S, (0, -1), 1)
      E = np.delete(epsilon, (0, -1), 0)
      E = np.delete(E, (0, -1), 1)
      
      m      = np.append(m, mag(S)[0])
      M      = np.append(M, mag(S)[1])
      H      = np.append(H, h)
      Energy = np.append(Energy, np.average(E))

      # output files
      if (temp_n % io_freq == 0):
        '''
        output info files

        '''
        output_fig(temp_n+1, S, clim_spin, t+dt, "norm_spin")
        output_fig(temp_n+1, E, clim_energy, t+dt, "norm_energy")
        print(f"{temp_n}, t = {np.round(t+dt, 2)}, succeed to output!")

      # update time and steps
      temp_n += 1
      t += dt
      if t + dt > tmax:
        dt = tmax - t

        # plot the last figure with "contour"
        # plot_ct(S, f"spin, t = {np.round(t, 2)}", clim_spin, size = 8, dpi = 80)
        # plot_ct(E, f"energy, t = {np.round(t, 2)}", clim_energy, size = 8, dpi = 80)
    t2 = time.time()
    
    # output
    T = np.linspace(0, tmax, temp_n+1)
    
    figure(figsize=(9, 6), dpi=80)
    plt.xlabel('time [code unit]')
    plt.ylabel('m [code unit]')
    plt.title(f'Magnetization per spin with {size}, (normal)')
    plt.plot(T, m, '--.', alpha = .6)
    plt.grid(True)
    plt.show()
    
    # figure(figsize=(9, 6), dpi=80)
    # plt.xlabel('time [code unit]')
    # plt.ylabel('M [code unit]')
    # plt.title(f'Magnetization with {size}')
    # plt.plot(T, M, '--.', alpha = .6)
    # plt.grid(True)
    # plt.show()
    
    figure(figsize=(9, 6), dpi=80)
    plt.xlabel('time [code unit]')
    plt.ylabel('Energy [code unit]')
    plt.title(f'Average Energy vs Time, (normal)')
    plt.plot(T, Energy, '--.', alpha = .6)
    plt.grid(True)
    plt.show()
    
    HH = np.sort(H, axis=None)
    mm = np.sort(m, axis=None)

    xdata = HH
    ydata = mm
    
    # fitting m-h
    popt, pcov = curve_fit(func_exp, xdata, ydata, bounds=(-0.5, [2., 50., 2., 1.]))
    popt_, pcov_ = curve_fit(func_repo, xdata, ydata, bounds=(0.5, [2., 10., 2., 1.]), p0=([2,5,1,0.6])) 
    cubic = CS(xdata, ydata)
    
    figure(figsize=(9, 6), dpi=80)
    plt.xlabel('h [code unit]')
    plt.ylabel('m [code unit]')
    plt.title(f'Magnetization per spin vs outer field, (normal)')
    plt.plot(xdata, cubic[0],'--c', alpha = .5, label = f'Cubic Spline')
    plt.plot(xdata, func_exp(xdata, *popt), '--g', alpha = .5, label = f'exp fit with \n popt = {np.round(popt, 2)}')
    plt.plot(xdata, func_exp(xdata, *popt_), '--b', alpha = .5, label = f'reciprocal fit with \n popt = {np.round(popt_,2)}')
    plt.plot(HH, mm, '--.', color = 'coral', alpha = .3, label='data')
    plt.legend()
    plt.grid(True)
    plt.show()

    x = np.zeros(np.size(mm)-1)
    x_size = int(np.size(x))
    def f(x):
      return -popt[0] * np.exp(-popt[1] * x + popt[2]) + popt[3]
    xx = X(f, ydata, x, x_size)
    HH = np.delete(HH, [-1], axis=0)
    figure(figsize=(9, 6), dpi=80)
    plt.xlabel('h [code unit]')
    plt.ylabel('X [code unit]')
    plt.title(f'Susceptibility vs outer field, (normal)')
    plt.plot(xdata, cubic[1],'--.c', alpha = .5, label = f'Cubic Spline')
    plt.plot(HH, xx, '--.b', alpha = .5, label = 'Curve fit (exp)')
    plt.grid(True)
    plt.show()
    
    return print("Done! Time = ", np.round(t2 - t1, 3), "[s]")

# %% [markdown]
# #### main equality

# %%
# main (loop of time)
def main_e(N, n, tmax, spin, J, sigma_x, sigma_y, eta, *args):
    '''
    This is the main loop function, and it will also output the figures(.png).

    :para N: is the total number of sites
    :para n: is total number of time steps
    :para T: is the total time
    :para spin: is the spin matrix
    :para J: is configuration constant (positive means paramagnetism)
    :para sigma_x: is a standard deviation in x-direction
    :para sigma_y: is a standard deviation in y-direction
    :para eta: absorbing rate constant
    '''

    dt = 7
    t = 0
    temp_n = 0
    
    # initial setup checking 
    bk = bkg(N, sigma_x, sigma_y)
    h = 0.2 * np.average(bk) # set no bkg influences in the beginning
    Ei =energy(spin, N, J, h)
    Ei = np.delete(Ei, (0, -1), 0)
    Ei = np.delete(Ei, (0, -1), 1)
    Si = np.delete(spin, (0, -1), 0)
    Si = np.delete(Si, (0, -1), 1)
    
    m      = np.array([mag(Si)[0]])
    M      = np.array([mag(Si)[1]])
    H      = np.array([h])
    Energy = np.array([np.average(Ei)])
    
    # initial output
    clim_spin = np.max(np.abs(Si))
    clim_energy = np.max(np.abs(Ei))
    output_fig(temp_n, Si, clim_spin, t, "eq_spin")
    output_fig(temp_n, Ei, clim_energy, t, "eq_energy")
    print("Initial t = 0, succeed to output!")

    t1 = time.time()
    while t < tmax:
      # update data
      epsilon =energy(spin, N, J, h)
      spin = self_eq(N, t, tmax, spin, bk, eta, se, s_time)[0]
      h = 0.2 * np.average(self_eq(N, t, tmax, spin, bk, eta, se, s_time)[1])
      
      # prune margins
      S = np.delete(spin, (0, -1), 0)
      S = np.delete(S, (0, -1), 1)
      E = np.delete(epsilon, (0, -1), 0)
      E = np.delete(E, (0, -1), 1)
      
      m      = np.append(m, mag(S)[0])
      M      = np.append(M, mag(S)[1])
      H      = np.append(H, h)
      Energy = np.append(Energy, np.average(E))

      # output files
      if (temp_n % io_freq == 0):
        '''
        output info files

        '''
        output_fig(temp_n+1, S, clim_spin, t+dt, "eq_spin")
        output_fig(temp_n+1, E, clim_energy, t+dt, "eq_energy")
        print(f"{temp_n}, t = {np.round(t+dt, 2)}, succeed to output!")

      # update time and steps
      temp_n += 1
      t += dt
      if t + dt > tmax:
        dt = tmax - t

        # plot the last figure with "contour"
        # plot_ct(S, f"spin, t = {np.round(t, 2)}", clim_spin, size = 8, dpi = 80)
        # plot_ct(E, f"energy, t = {np.round(t, 2)}", clim_energy, size = 8, dpi = 80)
    t2 = time.time()
    
    # output
    T = np.linspace(0, tmax, temp_n+1)
    
    figure(figsize=(9, 6), dpi=80)
    plt.xlabel('time [code unit]')
    plt.ylabel('m [code unit]')
    plt.title(f'Magnetization per spin with {size}, (Equality)')
    plt.plot(T, m, '--.', alpha = .6)
    plt.grid(True)
    plt.show()
    
    # figure(figsize=(9, 6), dpi=80)
    # plt.xlabel('time [code unit]')
    # plt.ylabel('M [code unit]')
    # plt.title(f'Magnetization with {size}')
    # plt.plot(T, M, '--.', alpha = .6)
    # plt.grid(True)
    # plt.show()
    
    figure(figsize=(9, 6), dpi=80)
    plt.xlabel('time [code unit]')
    plt.ylabel('Energy [code unit]')
    plt.title(f'Average Energy vs Time, (Equality)')
    plt.plot(T, Energy, '--.', alpha = .6)
    plt.grid(True)
    plt.show()
    
    HH = np.sort(H, axis=None)
    mm = np.sort(m, axis=None)

    # fitting m-h
    xdata, ydata = HH, mm
    
    # fitting m-h
    popt, pcov = curve_fit(func_exp, xdata, ydata, bounds=(-0.5, [2., 50., 2., 1.]))
    popt_, pcov_ = curve_fit(func_repo, xdata, ydata, bounds=(0.5, [2., 10., 1., 1.]), p0=([2,5,1,0.6])) 
    cubic = CS(xdata, ydata)

    figure(figsize=(9, 6), dpi=80)
    plt.xlabel('h [code unit]')
    plt.ylabel('m [code unit]')
    plt.title(f'Magnetization per spin vs outer field, (Equality)')
    plt.plot(xdata, cubic[0],'--c', alpha = .5, label = f'Cubic Spline')
    plt.plot(xdata, func_exp(xdata, *popt), '--g', alpha = .5, label = f'exp fit with \n popt = {np.round(popt, 2)}')
    plt.plot(xdata, func_exp(xdata, *popt_), '--b', alpha = .5, label = f'reciprocal fit with \n popt = {np.round(popt_,2)}')
    plt.plot(HH, mm, '--.', color = 'coral', alpha = .3, label='data')
    plt.legend()
    plt.grid(True)
    plt.show()

    x = np.zeros(np.size(mm)-1)
    x_size = int(np.size(x))
    def f(x):
      return -popt[0] * np.exp(-popt[1] * x + popt[2]) + popt[3]
    xx = X(f, ydata, x, x_size)
    HH = np.delete(HH, [-1], axis=0)
    figure(figsize=(9, 6), dpi=80)
    plt.xlabel('h [code unit]')
    plt.ylabel('X [code unit]')
    plt.title(f'Susceptibility vs outer field, (Equality)')
    plt.plot(xdata, cubic[1],'--.c', alpha = .5, label = f'Cubic Spline')
    plt.plot(HH, xx, '--.b', alpha = .5, label = 'Curve fit (exp)')
    plt.grid(True)
    plt.show()
    
    return print("Done! Time = ", np.round(t2 - t1, 3), "[s]")

# %% [markdown]
# #### main justice

# %%
# main (loop of time)
def main_j(N, n, tmax, spin, J, sigma_x, sigma_y, eta, *args):
    '''
    This is the main loop function, and it will also output the figures(.png).

    :para N: is the total number of sites
    :para n: is total number of time steps
    :para T: is the total time
    :para spin: is the spin matrix
    :para J: is configuration constant (positive means paramagnetism)
    :para sigma_x: is a standard deviation in x-direction
    :para sigma_y: is a standard deviation in y-direction
    :para eta: absorbing rate constant
    '''

    dt = 7
    t = 0
    temp_n = 0
    
    # initial setup checking 
    bk = bkg(N, sigma_x, sigma_y)
    h = 0.2 * np.average(bk) # set no bkg influences in the beginning
    Ei =energy(spin, N, J, h)
    Ei = np.delete(Ei, (0, -1), 0)
    Ei = np.delete(Ei, (0, -1), 1)
    Si = np.delete(spin, (0, -1), 0)
    Si = np.delete(Si, (0, -1), 1)
    
    m      = np.array([mag(Si)[0]])
    M      = np.array([mag(Si)[1]])
    H      = np.array([h])
    Energy = np.array([np.average(Ei)])
    
    # initial output
    clim_spin = np.max(np.abs(Si))
    clim_energy = np.max(np.abs(Ei))
    output_fig(temp_n, Si, clim_spin, t, "ju_spin")
    output_fig(temp_n, Ei, clim_energy, t, "ju_energy")
    print("Initial t = 0, succeed to output!")

    t1 = time.time()
    while t < tmax:
      # update data
      epsilon =energy(spin, N, J, h)
      spin = self_ju(N, t, tmax, spin, bk, eta, sj, s_time)[0]
      h = 0.2 * np.average(self_eq(N, t, tmax, spin, bk, eta, sj, s_time)[1])
      
      # prune margins
      S = np.delete(spin, (0, -1), 0)
      S = np.delete(S, (0, -1), 1)
      E = np.delete(epsilon, (0, -1), 0)
      E = np.delete(E, (0, -1), 1)
      
      m      = np.append(m, mag(S)[0])
      M      = np.append(M, mag(S)[1])
      H      = np.append(H, h)
      Energy = np.append(Energy, np.average(E))

      # output files
      if (temp_n % io_freq == 0):
        '''
        output info files

        '''
        output_fig(temp_n+1, S, clim_spin, t+dt, "ju_spin")
        output_fig(temp_n+1, E, clim_energy, t+dt, "ju_energy")
        print(f"{temp_n}, t = {np.round(t+dt, 2)}, succeed to output!")

      # update time and steps
      temp_n += 1
      t += dt
      if t + dt > tmax:
        dt = tmax - t

        # plot the last figure with "contour"
        # plot_ct(S, f"spin, t = {np.round(t, 2)}", clim_spin, size = 8, dpi = 80)
        # plot_ct(E, f"energy, t = {np.round(t, 2)}", clim_energy, size = 8, dpi = 80)
    t2 = time.time()
    
    # output
    T = np.linspace(0, tmax, temp_n+1)
    
    figure(figsize=(9, 6), dpi=80)
    plt.xlabel('time [code unit]')
    plt.ylabel('m [code unit]')
    plt.title(f'Magnetization per spin with {size}, (Justice)')
    plt.plot(T, m, '--.', alpha = .6)
    plt.grid(True)
    plt.show()
    
    # figure(figsize=(9, 6), dpi=80)
    # plt.xlabel('time [code unit]')
    # plt.ylabel('M [code unit]')
    # plt.title(f'Magnetization with {size}')
    # plt.plot(T, M, '--.', alpha = .6)
    # plt.grid(True)
    # plt.show()
    
    figure(figsize=(9, 6), dpi=80)
    plt.xlabel('time [code unit]')
    plt.ylabel('Energy [code unit]')
    plt.title(f'Average Energy vs Time, (Justice)')
    plt.plot(T, Energy, '--.', alpha = .6)
    plt.grid(True)
    plt.show()
    
    HH = np.sort(H, axis=None).flatten()
    mm = np.sort(m, axis=None).flatten()

    # fitting m-h
    xdata, ydata = HH, mm
    cubic = CS(xdata, ydata)
    
    popt, pcov = curve_fit(func_exp, xdata, ydata, bounds=(-0.5, [2., 50., 2., 1.]))
    popt_, pcov_ = curve_fit(func_repo, xdata, ydata, bounds=(0.5, [2., 10., 2., 1.]), p0=([2,5,1,0.6])) 

    figure(figsize=(9, 6), dpi=80)
    plt.xlabel('h [code unit]')
    plt.ylabel('m [code unit]')
    plt.title(f'Magnetization per spin vs outer field, (Justice)')
    plt.plot(xdata, cubic[0],'--c', alpha = .5, label = f'Cubic Spline')
    plt.plot(xdata, func_exp(xdata, *popt), '--g', alpha = .5, label = f'exp fit with \n popt = {np.round(popt, 2)}')
    plt.plot(xdata, func_exp(xdata, *popt_), '--b', alpha = .5, label = f'reciprocal fit with \n popt = {np.round(popt_,2)}')
    plt.plot(HH, mm, '--.', color = 'coral', alpha = .3, label='data')
    plt.legend()
    plt.grid(True)
    plt.show()
    
    x = np.zeros(np.size(mm)-1)
    x_size = int(np.size(x))
    def f(x):
      return -popt[0] * np.exp(-popt[1] * x + popt[2]) + popt[3]
    xx = X(f, ydata, x, x_size)
    HH = np.delete(HH, [-1], axis=0)
    figure(figsize=(9, 6), dpi=80)
    plt.xlabel('h [code unit]')
    plt.ylabel('X [code unit]')
    plt.title(f'Susceptibility vs outer field, (Justice)')
    plt.plot(xdata, cubic[1],'--.c', alpha = .5, label = f'Cubic Spline')
    plt.plot(HH, xx, '--.b', alpha = .5, label = 'Curve fit (exp)')
    plt.grid(True)
    plt.show()

    return print("Done! Time = ", np.round(t2 - t1, 3), "[s]")

# %% [markdown]
# ### Execution

# %%
'''
main for normal loop
'''
print("Norm \n")
t1 = time.time()
spin = grid_generator(width, length, init_rank = 3.0, dec = 2)[1] # include boundary
main(N, n, tmax, spin, J, sigma_x, sigma_y, eta)
t2 = time.time()

print(f"Taking {np.round((t2 - t1), 3)} [s]")
print("Finish!")
# Out:
# Norm
#
# Initial t = 0, succeed to output!
# 0, t = 7, succeed to output!
# 4, t = 35, succeed to output!
# 8, t = 63, succeed to output!
# 12, t = 91, succeed to output!
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[303], line 7
#       5 t1 = time.time()
#       6 spin = grid_generator(width, length, init_rank = 3.0, dec = 2)[1] # include boundary
# ----> 7 main(N, n, tmax, spin, J, sigma_x, sigma_y, eta)
#       8 t2 = time.time()
#      10 print(f"Taking {np.round((t2 - t1), 3)} [s]")
#
# Cell In[300], line 116, in main(N, n, tmax, spin, J, sigma_x, sigma_y, eta, *args)
#     114 popt, pcov = curve_fit(func_exp, xdata, ydata, bounds=(-0.5, [2., 50., 2., 1.]))
#     115 popt_, pcov_ = curve_fit(func_repo, xdata, ydata, bounds=(0.5, [2., 10., 2., 1.]), p0=([2,5,1,0.6]))
# --> 116 cubic = CS(xdata, ydata)
#     118 figure(figsize=(9, 6), dpi=80)
#     119 plt.xlabel('h [code unit]')
#
# Cell In[296], line 3, in CS(x, y)
#       1 def CS(x, y):
#       2   # cs = CubicSpline(x, y)
# ----> 3   cs = InterpolatedUnivariateSpline(x, y)
#       4   der = UnivariateSpline(x, y).derivatives(x)
#       5   return cs, der
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/comphyslab/lib/python3.9/site-packages/scipy/interpolate/_fitpack2.py:664, in InterpolatedUnivariateSpline.__init__(self, x, y, w, bbox, k, ext, check_finite)
#     661 x, y, w, bbox, self.ext = self.validate_input(x, y, w, bbox, k, None,
#     662                                     ext, check_finite)
#     663 if not np.all(diff(x) > 0.0):
# --> 664     raise ValueError('x must be strictly increasing')
#     666 # _data == x,y,w,xb,xe,k,s,n,t,c,fp,fpint,nrdata,ier
#     667 self._data = dfitpack.fpcurf0(x, y, k, w=w, xb=bbox[0],
#     668                               xe=bbox[1], s=0)
#
# ValueError: x must be strictly increasing

# %%
'''
main loop of equality
'''
print("Eq \n")
t1 = time.time()
spin = grid_generator(width, length, init_rank = 3.0, dec = 2)[1] # include boundary
main_e(N, n, tmax, spin, J, sigma_x, sigma_y, eta, se, s_time)
t2 = time.time()

print(f"Taking {np.round((t2 - t1), 3)} [s]")
print("Finish!")
# Out:
# Eq
#
# Initial t = 0, succeed to output!
# 0, t = 7, succeed to output!
# 4, t = 35, succeed to output!
# 8, t = 63, succeed to output!
# 12, t = 91, succeed to output!
# 16, t = 119, succeed to output!
# 20, t = 147, succeed to output!
# 24, t = 175, succeed to output!
# 28, t = 203, succeed to output!
# 32, t = 231, succeed to output!
# 36, t = 259, succeed to output!
# 40, t = 287, succeed to output!
# 44, t = 315, succeed to output!
# 48, t = 343, succeed to output!
# 52, t = 371, succeed to output!
# 56, t = 399, succeed to output!
# 60, t = 427, succeed to output!
# 64, t = 455, succeed to output!
# 68, t = 483, succeed to output!
# 72, t = 511, succeed to output!
# 76, t = 539, succeed to output!
# 80, t = 567, succeed to output!
# 84, t = 595, succeed to output!
# 88, t = 623, succeed to output!
# 92, t = 651, succeed to output!
# 96, t = 679, succeed to output!
# 100, t = 707, succeed to output!
# 104, t = 735, succeed to output!
# 108, t = 763, succeed to output!
# 112, t = 791, succeed to output!
# 116, t = 819, succeed to output!
# 120, t = 847, succeed to output!
# 124, t = 875, succeed to output!
# 128, t = 903, succeed to output!
# 132, t = 931, succeed to output!
# 136, t = 959, succeed to output!
# 140, t = 987, succeed to output!
# 144, t = 1015, succeed to output!
# 148, t = 1043, succeed to output!
# 152, t = 1071, succeed to output!
# 156, t = 1099, succeed to output!
# 160, t = 1127, succeed to output!
# 164, t = 1155, succeed to output!
# 168, t = 1183, succeed to output!
# 172, t = 1211, succeed to output!
# 176, t = 1239, succeed to output!
# 180, t = 1267, succeed to output!
# 184, t = 1295, succeed to output!
# 188, t = 1323, succeed to output!
# 192, t = 1351, succeed to output!
# 196, t = 1379, succeed to output!
# 200, t = 1407, succeed to output!
# 204, t = 1435, succeed to output!
# 208, t = 1463, succeed to output!
# 212, t = 1491, succeed to output!
# 216, t = 1519, succeed to output!
# 220, t = 1547, succeed to output!
# 224, t = 1575, succeed to output!
# 228, t = 1603, succeed to output!
# 232, t = 1631, succeed to output!
# 236, t = 1659, succeed to output!
# 240, t = 1687, succeed to output!
# 244, t = 1715, succeed to output!
# 248, t = 1743, succeed to output!
# 252, t = 1771, succeed to output!
# 256, t = 1799, succeed to output!
# 260, t = 1827, succeed to output!
# 264, t = 1855, succeed to output!
# 268, t = 1883, succeed to output!
# 272, t = 1911, succeed to output!
# 276, t = 1939, succeed to output!
# 280, t = 1967, succeed to output!
# 284, t = 1995, succeed to output!
# 288, t = 2023, succeed to output!
# 292, t = 2051, succeed to output!
# 296, t = 2079, succeed to output!
# 300, t = 2107, succeed to output!
# 304, t = 2135, succeed to output!
# 308, t = 2163, succeed to output!
# 312, t = 2191, succeed to output!
# 316, t = 2219, succeed to output!
# 320, t = 2247, succeed to output!
# 324, t = 2275, succeed to output!
# 328, t = 2303, succeed to output!
# 332, t = 2331, succeed to output!
# 336, t = 2359, succeed to output!
# 340, t = 2387, succeed to output!
# 344, t = 2415, succeed to output!
# 348, t = 2443, succeed to output!
# 352, t = 2471, succeed to output!
# 356, t = 2499, succeed to output!
# 360, t = 2527, succeed to output!
# 364, t = 2555, succeed to output!
# 368, t = 2583, succeed to output!
# 372, t = 2611, succeed to output!
# 376, t = 2639, succeed to output!
# 380, t = 2667, succeed to output!
# 384, t = 2695, succeed to output!
# 388, t = 2723, succeed to output!
# 392, t = 2751, succeed to output!
# 396, t = 2779, succeed to output!
# 400, t = 2807, succeed to output!
# 404, t = 2835, succeed to output!
# 408, t = 2863, succeed to output!
# 412, t = 2891, succeed to output!
# 416, t = 2919, succeed to output!
# 420, t = 2947, succeed to output!
# 424, t = 2975, succeed to output!
# 428, t = 3003, succeed to output!
# 432, t = 3031, succeed to output!
# 436, t = 3059, succeed to output!
# 440, t = 3087, succeed to output!
# 444, t = 3115, succeed to output!
# 448, t = 3143, succeed to output!
# 452, t = 3171, succeed to output!
# 456, t = 3199, succeed to output!
# 460, t = 3227, succeed to output!
# 464, t = 3255, succeed to output!
# 468, t = 3283, succeed to output!
# 472, t = 3311, succeed to output!
# 476, t = 3339, succeed to output!
# 480, t = 3367, succeed to output!
# 484, t = 3395, succeed to output!
# 488, t = 3423, succeed to output!
# 492, t = 3451, succeed to output!
# 496, t = 3479, succeed to output!
# 500, t = 3507, succeed to output!
# 504, t = 3535, succeed to output!
# 508, t = 3563, succeed to output!
# 512, t = 3591, succeed to output!
# 516, t = 3619, succeed to output!
# 520, t = 3647, succeed to output!
# 524, t = 3675, succeed to output!
# 528, t = 3703, succeed to output!
# 532, t = 3731, succeed to output!
# 536, t = 3759, succeed to output!
# 540, t = 3787, succeed to output!
# 544, t = 3815, succeed to output!
# 548, t = 3843, succeed to output!
# 552, t = 3871, succeed to output!
# 556, t = 3899, succeed to output!
# 560, t = 3927, succeed to output!
# 564, t = 3955, succeed to output!
# 568, t = 3983, succeed to output!
# 572, t = 4011, succeed to output!
# 576, t = 4039, succeed to output!
# 580, t = 4067, succeed to output!
# 584, t = 4095, succeed to output!
# 588, t = 4123, succeed to output!
# 592, t = 4151, succeed to output!
# 596, t = 4179, succeed to output!
# 600, t = 4207, succeed to output!
# 604, t = 4235, succeed to output!
# 608, t = 4263, succeed to output!
# 612, t = 4291, succeed to output!
# 616, t = 4319, succeed to output!
# Done! Time =  78.865 [s]
# Taking 79.819 [s]
# Finish!

# %%
'''
main loop of jutice
'''
print("Ju \n")
t1 = time.time()
spin = grid_generator(width, length, init_rank = 3.0, dec = 2)[1] # include boundary
main_j(N, n, tmax, spin, J, sigma_x, sigma_y, eta, se, s_time)
t2 = time.time()

print(f"Taking {np.round((t2 - t1), 3)} [s]")
print("Finish!")
# Out:
# Ju
#
# Initial t = 0, succeed to output!
# 0, t = 7, succeed to output!
# 4, t = 35, succeed to output!
# 8, t = 63, succeed to output!
# 12, t = 91, succeed to output!
# 16, t = 119, succeed to output!
# 20, t = 147, succeed to output!
# 24, t = 175, succeed to output!
# 28, t = 203, succeed to output!
# 32, t = 231, succeed to output!
# 36, t = 259, succeed to output!
# 40, t = 287, succeed to output!
# 44, t = 315, succeed to output!
# 48, t = 343, succeed to output!
# 52, t = 371, succeed to output!
# 56, t = 399, succeed to output!
# 60, t = 427, succeed to output!
# 64, t = 455, succeed to output!
# 68, t = 483, succeed to output!
# 72, t = 511, succeed to output!
# 76, t = 539, succeed to output!
# 80, t = 567, succeed to output!
# 84, t = 595, succeed to output!
# 88, t = 623, succeed to output!
# 92, t = 651, succeed to output!
# 96, t = 679, succeed to output!
# 100, t = 707, succeed to output!
# 104, t = 735, succeed to output!
# 108, t = 763, succeed to output!
# 112, t = 791, succeed to output!
# 116, t = 819, succeed to output!
# 120, t = 847, succeed to output!
# 124, t = 875, succeed to output!
# 128, t = 903, succeed to output!
# 132, t = 931, succeed to output!
# 136, t = 959, succeed to output!
# 140, t = 987, succeed to output!
# 144, t = 1015, succeed to output!
# 148, t = 1043, succeed to output!
# 152, t = 1071, succeed to output!
# 156, t = 1099, succeed to output!
# 160, t = 1127, succeed to output!
# 164, t = 1155, succeed to output!
# 168, t = 1183, succeed to output!
# 172, t = 1211, succeed to output!
# 176, t = 1239, succeed to output!
# 180, t = 1267, succeed to output!
# 184, t = 1295, succeed to output!
# 188, t = 1323, succeed to output!
# 192, t = 1351, succeed to output!
# 196, t = 1379, succeed to output!
# 200, t = 1407, succeed to output!
# 204, t = 1435, succeed to output!
# 208, t = 1463, succeed to output!
# 212, t = 1491, succeed to output!
# 216, t = 1519, succeed to output!
# 220, t = 1547, succeed to output!
# 224, t = 1575, succeed to output!
# 228, t = 1603, succeed to output!
# 232, t = 1631, succeed to output!
# 236, t = 1659, succeed to output!
# 240, t = 1687, succeed to output!
# 244, t = 1715, succeed to output!
# 248, t = 1743, succeed to output!
# 252, t = 1771, succeed to output!
# 256, t = 1799, succeed to output!
# 260, t = 1827, succeed to output!
# 264, t = 1855, succeed to output!
# 268, t = 1883, succeed to output!
# 272, t = 1911, succeed to output!
# 276, t = 1939, succeed to output!
# 280, t = 1967, succeed to output!
# 284, t = 1995, succeed to output!
# 288, t = 2023, succeed to output!
# 292, t = 2051, succeed to output!
# 296, t = 2079, succeed to output!
# 300, t = 2107, succeed to output!
# 304, t = 2135, succeed to output!
# 308, t = 2163, succeed to output!
# 312, t = 2191, succeed to output!
# 316, t = 2219, succeed to output!
# 320, t = 2247, succeed to output!
# 324, t = 2275, succeed to output!
# 328, t = 2303, succeed to output!
# 332, t = 2331, succeed to output!
# 336, t = 2359, succeed to output!
# 340, t = 2387, succeed to output!
# 344, t = 2415, succeed to output!
# 348, t = 2443, succeed to output!
# 352, t = 2471, succeed to output!
# 356, t = 2499, succeed to output!
# 360, t = 2527, succeed to output!
# 364, t = 2555, succeed to output!
# 368, t = 2583, succeed to output!
# 372, t = 2611, succeed to output!
# 376, t = 2639, succeed to output!
# 380, t = 2667, succeed to output!
# 384, t = 2695, succeed to output!
# 388, t = 2723, succeed to output!
# 392, t = 2751, succeed to output!
# 396, t = 2779, succeed to output!
# 400, t = 2807, succeed to output!
# 404, t = 2835, succeed to output!
# 408, t = 2863, succeed to output!
# 412, t = 2891, succeed to output!
# 416, t = 2919, succeed to output!
# 420, t = 2947, succeed to output!
# 424, t = 2975, succeed to output!
# 428, t = 3003, succeed to output!
# 432, t = 3031, succeed to output!
# 436, t = 3059, succeed to output!
# 440, t = 3087, succeed to output!
# 444, t = 3115, succeed to output!
# 448, t = 3143, succeed to output!
# 452, t = 3171, succeed to output!
# 456, t = 3199, succeed to output!
# 460, t = 3227, succeed to output!
# 464, t = 3255, succeed to output!
# 468, t = 3283, succeed to output!
# 472, t = 3311, succeed to output!
# 476, t = 3339, succeed to output!
# 480, t = 3367, succeed to output!
# 484, t = 3395, succeed to output!
# 488, t = 3423, succeed to output!
# 492, t = 3451, succeed to output!
# 496, t = 3479, succeed to output!
# 500, t = 3507, succeed to output!
# 504, t = 3535, succeed to output!
# 508, t = 3563, succeed to output!
# 512, t = 3591, succeed to output!
# 516, t = 3619, succeed to output!
# 520, t = 3647, succeed to output!
# 524, t = 3675, succeed to output!
# 528, t = 3703, succeed to output!
# 532, t = 3731, succeed to output!
# 536, t = 3759, succeed to output!
# 540, t = 3787, succeed to output!
# 544, t = 3815, succeed to output!
# 548, t = 3843, succeed to output!
# 552, t = 3871, succeed to output!
# 556, t = 3899, succeed to output!
# 560, t = 3927, succeed to output!
# 564, t = 3955, succeed to output!
# 568, t = 3983, succeed to output!
# 572, t = 4011, succeed to output!
# 576, t = 4039, succeed to output!
# 580, t = 4067, succeed to output!
# 584, t = 4095, succeed to output!
# 588, t = 4123, succeed to output!
# 592, t = 4151, succeed to output!
# 596, t = 4179, succeed to output!
# 600, t = 4207, succeed to output!
# 604, t = 4235, succeed to output!
# 608, t = 4263, succeed to output!
# 612, t = 4291, succeed to output!
# 616, t = 4319, succeed to output!
# Done! Time =  79.792 [s]
# Taking 80.826 [s]
# Finish!

# %% [markdown]
# ### Creat GIF

# %%
'''
eq spin
'''

# Create the frames
frames = []
imgs = glob.glob(f"{io_folder_fig}/fig_Common_Prosperity_eq_spin_*.png")
imgs.sort()
# check the sorted result
print(imgs)

for i in imgs:
    new_frame = Image.open(i)
    frames.append(new_frame)

# Save into a GIF file that loops forever
frames[0].save('eq_spin.gif', format='GIF',
                append_images=frames[1:],
                save_all=True,
                duration=200, loop=0)

print("Done!")
# Out:
# ['fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_000.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_001.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_005.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_009.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_013.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_017.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_021.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_025.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_029.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_033.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_037.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_041.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_045.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_049.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_053.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_057.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_061.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_065.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_069.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_073.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_077.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_081.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_085.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_089.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_093.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_097.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_101.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_105.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_109.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_113.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_117.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_121.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_125.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_129.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_133.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_137.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_141.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_145.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_149.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_153.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_157.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_161.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_165.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_169.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_173.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_177.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_181.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_185.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_189.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_193.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_197.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_201.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_205.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_209.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_213.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_217.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_221.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_225.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_229.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_233.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_237.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_241.png', 'fig_Common_Prosperity/fig_Common_Prosperity_eq_spin_245.png', 'fig_Common_Prosperity/fig_Com ...
# Done!

# %%
'''
jutice spin
'''

# Create the frames
frames = []
imgs = glob.glob(f"{io_folder_fig}/fig_Common_Prosperity_ju_spin_*.png")
imgs.sort()
# check the sorted result
print(imgs)

for i in imgs:
    new_frame = Image.open(i)
    frames.append(new_frame)

# Save into a GIF file that loops forever
frames[0].save('ju_spin.gif', format='GIF',
                append_images=frames[1:],
                save_all=True,
                duration=200, loop=0)

print("Done!")
# Out:
# ['fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_000.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_001.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_005.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_009.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_013.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_017.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_021.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_025.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_029.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_033.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_037.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_041.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_045.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_049.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_053.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_057.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_061.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_065.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_069.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_073.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_077.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_081.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_085.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_089.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_093.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_097.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_101.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_105.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_109.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_113.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_117.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_121.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_125.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_129.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_133.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_137.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_141.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_145.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_149.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_153.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_157.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_161.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_165.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_169.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_173.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_177.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_181.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_185.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_189.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_193.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_197.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_201.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_205.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_209.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_213.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_217.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_221.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_225.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_229.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_233.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_237.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_241.png', 'fig_Common_Prosperity/fig_Common_Prosperity_ju_spin_245.png', 'fig_Common_Prosperity/fig_Com ...
# Done!

# %%
'''
norm spin
'''

# Create the frames
frames = []
imgs = glob.glob(f"{io_folder_fig}/fig_Common_Prosperity_norm_spin_*.png")
imgs.sort()
# check the sorted result
print(imgs)

for i in imgs:
    new_frame = Image.open(i)
    frames.append(new_frame)

# Save into a GIF file that loops forever
frames[0].save('norm_spin.gif', format='GIF',
                append_images=frames[1:],
                save_all=True,
                duration=200, loop=0)

print("Done!")
# Out:
# ['fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_000.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_001.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_005.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_009.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_013.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_017.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_021.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_025.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_029.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_033.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_037.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_041.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_045.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_049.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_053.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_057.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_061.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_065.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_069.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_073.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_077.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_081.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_085.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_089.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_093.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_097.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_101.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_105.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_109.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_113.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_117.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_121.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_125.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_129.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_133.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_137.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_141.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_145.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_149.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_153.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_157.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_161.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_165.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_169.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_173.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_177.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_181.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_185.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_189.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_193.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_197.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_201.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_205.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_209.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_213.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_217.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_221.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_225.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_229.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_233.png', 'fig_Common_Prosperity/fig_Common_Prosperity_norm_spin_237.png', 'fig_Common_Prosperity/fig_Common_ ...
# Done!

# %%
# '''
# Energy
# '''

# # Create the frames
# frames = []
# imgs = glob.glob(f"{io_folder_fig}/fig_Common_Prosperity_norm_energy_*.png")
# imgs.sort()
# # check the sorted result
# print(imgs)

# for i in imgs:
#     new_frame = Image.open(i)
#     frames.append(new_frame)

# # Save into a GIF file that loops forever
# frames[0].save('energy.gif', format='GIF',
#                 append_images=frames[1:],
#                 save_all=True,
#                 duration=300, loop=0)

# print("Done!")
